# %% [markdown]
# # 0. Libraries and Path

# %%
import os
print(os.getcwd())
# Out:
# /home/fatemeh/thesis/kinodata-3D-affinity-prediction/examples

# %%
import torch

import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import tqdm

# %%
root = '/home/fatemeh/thesis/kinodata-3D-affinity-prediction'
os.chdir(root)

# %% [markdown]
# Load the probes

# %%
prob_dir = root + '/data/probing'
# Out:
# /home/fatemeh/thesis/kinodata-3D-affinity-prediction/data/probing

# %% [markdown]
# # 1. Read dict of X

# %% [markdown]
# # 2. Unbatch

# %% [markdown]
# # 3. Find the complex from ident_to_index
# Load indent to index json

# %% [markdown]
# # 4. Get/Compute the y
# What would it be? the activity itself?

# %% [markdown]
# ## 4.1. y = activity

# %% [markdown]
# ## 4.2. y = number of Hydrogens

# %% [markdown]
# ## 4.3. y = MW of the whole complex
# Or number of total atoms?

# %% [markdown]
# ## 4.4. y = number of ??

# %% [markdown]
# # 5. Create a dataset of complex
# ``num_attention_heads`` $ \times \{hidden\_representation \to y\}$  for each complex
